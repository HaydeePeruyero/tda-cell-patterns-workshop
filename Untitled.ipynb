# %%
import os
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %%
api_url = (
    "https://api.github.com/repos/"
    "HaydeePeruyero/tda-cell-patterns-workshop/contents/data/datos_proyecto"
)

contenido = requests.get(api_url).json()

archivos = sorted([
    f["name"]
    for f in contenido
    if f["name"].endswith(".csv")
])

print("Archivos encontrados:")
for archivo in archivos:
    print("-", archivo)

# ============================================================
# 2. RUTA RAW DE GITHUB (CORREGIDA)
# ============================================================

base_url = (
    "https://raw.githubusercontent.com/"
    "HaydeePeruyero/tda-cell-patterns-workshop/main/data/datos_proyecto/"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3425638/1458249642.py in <module>
#       4 )
#       5
# ----> 6 contenido = requests.get(api_url).json()
#       7
#       8 archivos = sorted([
#
# NameError: name 'requests' is not defined
